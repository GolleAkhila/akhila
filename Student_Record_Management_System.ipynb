# %% [markdown]
# <a href="https://colab.research.google.com/github/GolleAkhila/akhila/blob/main/Student_Record_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

FILE_NAME = "students.csv"

if not os.path.exists(FILE_NAME):
    with open(FILE_NAME, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Name", "Age", "Branch"])

print("Student database is ready!")
# Out:
# Student database is ready!

# %%
def add_student():
    try:
        student_id = input("Enter Student ID: ")
        name = input("Enter Student Name: ")
        age = int(input("Enter Student Age: "))
        branch = input("Enter Student Branch: ")

        with open(FILE_NAME, "a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([student_id, name, age, branch])

        print("Student added successfully!")

    except ValueError:
        print("Age must be a number!")

    except Exception as e:
        print("An error occurred:", e)

# %%
add_student()
# Out:
# Enter Student ID: 66
# Enter Student Name: maha
# Enter Student Age: abc
# Age must be a number!

# %%
def view_student():
    with open(FILE_NAME, "r", newline="") as file:
        reader = csv.reader(file)

        print("\n{:<10} {:<15} {:<10} {:<10}".format(
            "ID", "Name", "Age", "Branch"
        ))
        print("-" * 45)

        next(reader)

        for row in reader:
            print("{:<10} {:<15} {:<10} {:<10}".format(
                row[0], row[1], row[2], row[3]
            ))

# %%
view_student()
# Out:
# ID         Name            Age        Branch
# ---------------------------------------------
# 568        Akhila          21         CSE
# 595        Hyndhavi        21         CSE
# 777        Maha            20         EEE

# %%
def update_student():
    student_id = input("Enter Student ID to update: ")

    students = []

    with open(FILE_NAME, "r", newline="") as file:
        reader = csv.reader(file)
        header = next(reader)

        for row in reader:
            if row[0] == student_id:
                print("Student found!")

                name = input("Enter new name: ")
                age = input("Enter new age: ")
                branch = input("Enter new branch: ")

                row = [student_id, name, age, branch]

            students.append(row)

    with open(FILE_NAME, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(students)

    print("Student updated successfully!")

# %%
update_student()
# Out:
# Enter Student ID to update: 677
# Student found!
# Enter new name: Hasani
# Enter new age: 21
# Enter new branch: ECE
# Student updated successfully!

# %%
def delete_student():
    student_id = input("Enter Student ID to delete: ")

    students = []
    found = False

    with open(FILE_NAME, "r", newline="") as file:
        reader = csv.reader(file)
        header = next(reader)

        for row in reader:
            if row[0] == student_id:
                found = True
            else:
                students.append(row)

    with open(FILE_NAME, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
        writer.writerows(students)

    if found:
        print("Student deleted successfully!")
    else:
        print("Student ID not found!")

# %%
delete_student()
# Out:
# Enter Student ID to delete: 677
# Student deleted successfully!

# %%
try:
    age = int(input("Enter student age: "))
    print("Age:", age)

except ValueError:
    print("Please enter a valid number!")
# Out:
# Enter student age: abc
# Please enter a valid number!

# %%
try:
    age = int(input("Enter student age: "))
    print("Age:", age)

except ValueError:
    print("Invalid age!")

finally:
    print("Program execution completed.")
# Out:
# Enter student age: 21
# Age: 21
# Program execution completed.

# %%
while True:

    print("\n=================================")
    print(" STUDENT RECORD MANAGEMENT SYSTEM")
    print("=================================")

    print("1. Add Student")
    print("2. View Students")
    print("3. Update Student")
    print("4. Delete Student")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()

    elif choice == "2":
        view_student()

    elif choice == "3":
        update_student()

    elif choice == "4":
        delete_student()

    elif choice == "5":
        print("Thank you for using the system!")
        break

    else:
        print("Invalid choice! Please enter 1 to 5.")
# Out:
# ...
#  STUDENT RECORD MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice: 1
# Enter Student ID: 593
# Enter Student Name: Meghana
# Enter Student Age: 20
# Enter Student Branch: CSE
# Student added successfully!
#
# ...
#  STUDENT RECORD MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice: 2
#
# ID         Name            Age        Branch
# ---------------------------------------------
# 568        Akhila          21         CSE
# 595        Hyndhavi        21         CSE
# 777        Maha            20         EEE
# 68         Akhila          21         CSE
# 593        Meghana         20         CSE
#
# ...
#  STUDENT RECORD MANAGEMENT SYSTEM
# ...
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice: 4
# Enter Student ID to delete: 68
# Student deleted successfully!
#
# ...
#  STUDENT RECORD MANAGEMENT SYSTEM
# ...
